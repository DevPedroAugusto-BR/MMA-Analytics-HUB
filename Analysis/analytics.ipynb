# %%
import pandas as pd
import numpy as nd

# %%
df_with_age = pd.read_csv("MMA-Analytics-HUB\database\pro_mma_fighters_withAge.csv")

df_with_age.head()
df_with_age.columns

df_with_wins_and_loses = pd.read_csv("MMA-Analytics-HUB\database\ufc-fighters-statistics_WithWinsAndLoses.csv")
df_with_wins_and_loses.head()
df_with_wins_and_loses.columns

df_master_fights = pd.read_csv("MMA-Analytics-HUB\database\ufc-masterFights.csv")

df_master_fights.head()
df_master_fights.columns

df_upcomingFights = pd.read_csv("MMA-Analytics-HUB\database\upcomingFights.csv")

df_upcomingFights.head()
df_upcomingFights.columns
# Out:
# Index(['RedFighter', 'BlueFighter', 'RedOdds', 'BlueOdds', 'RedExpectedValue',
#        'BlueExpectedValue', 'Date', 'Location', 'Country', 'Winner',
#        ...
#        'FinishDetails', 'FinishRound', 'FinishRoundTime', 'TotalFightTimeSecs',
#        'RedDecOdds', 'BlueDecOdds', 'RSubOdds', 'BSubOdds', 'RKOOdds',
#        'BKOOdds'],
#       dtype='object', length=118)

# %%
df_final = unify_fighters_data(df_with_age, df_with_wins_and_loses, df_master_fights, df_upcomingFights)
print(df_final.head())
print(f"Número total de lutadores unificados: {len(df_final)}")
print(df_final.shape)
print(df_final.info())
print(df_final.tail())
print(df_final.columns)
# Out:
#                              url              name nickname_age  birth_date  \
# 0       /fighter/ASol-Kwon-20992        a-sol kwon          NaN  16/01/1985
# 1     /fighter/AJ-Agazarm-313227      a.j. agazarm         Leao  26/07/1989
# 2  /fighter/AJ-Lias-Mansor-78617  a.j. lias mansor         Pyro  16/05/1975
# 3       /fighter/AJ-McKee-194637        a.j. mckee    Mercenary  07/04/1995
# 4       /fighter/AJ-Siscoe-90807       a.j. siscoe     Let's Go  20/09/1990
#
#     age death_date                location        country height   weight  \
# 0  36.0        NaN     Mokpo, South Jeolla    South Korea   5'8"  155 lbs
# 1  32.0        NaN   Hollywood, California  United States   5'8"  145 lbs
# 2  46.0        NaN    Kota Kinabalu, Sabah       Malaysia   5'7"  143 lbs
# 3  26.0        NaN  Long Beach, California  United States  5'10"  145 lbs
# 4  30.0        NaN   St. Charles, Missouri  United States   5'7"  142 lbs
#
# ...
